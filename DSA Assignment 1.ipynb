# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# to display stats about data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#to display basic info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#to display no of samples of each class
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#Check null values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
#scatterplot
colors = ['red', 'orange' , 'blue']
Species = ['Iris-setosa', 'Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
  x = df[df['Species']==Species[i]]
  plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'] , c= colors[i] , label=Species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()

# %%
for i in range(3):
  x = df[df['Species']==Species[i]]
  plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'] , c= colors[i] , label=Species[i])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend()

# %%
for i in range(3):
  x = df[df['Species']==Species[i]]
  plt.scatter(x['SepalLengthCm'], x['PetalWidthCm'] , c= colors[i] , label=Species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')
plt.legend()

# %%
for i in range(3):
  x = df[df['Species']==Species[i]]
  plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'] , c= colors[i] , label=Species[i])
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.legend()

# %%
# data["column_name"].sum()

sum_data = df["SepalLengthCm"].sum()
mean_data = df["SepalLengthCm"].mean()
median_data = df['SepalLengthCm'].median()

print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333334
# Median: 5.8

# %% [markdown]
# # Extracting minimum and maximum from a column

# %%
min_data=df["SepalLengthCm"].min()
max_data=df["SepalLengthCm"].max()

print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 7.9

# %% [markdown]
# # Adding a column to the dataset

# %% [markdown]
# If want to add a new column in our dataset, as we are doing any calculations or extracting some information from the dataset, and if you want to save it a new column.

# %%
# For example, if we want to add a column let say "total_values",
# that means if you want to add all the integer value of that particular
# row and get total answer in the new column "total_values".
# first we will extract the columns which have integer values.
cols = df.columns

# it will print the list of column names.
print(cols)

# we will take that columns which have integer values.
cols = cols[1:5]

# we will save it in the new dataframe variable
data1 = df[cols]

# now adding new column "total_values" to dataframe data.
df["total_values"]=data1[cols].sum(axis=1)

# here axis=1 means you are working in rows,
# whereas axis=0 means you are working in columns.
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    total_values
# 0          10.2
# 1           9.5
# 2           9.4
# 3           9.4
# 4          10.2

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c18d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c18d_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_6c18d_level0_col1" class="col_heading level0 col1" >SepalLengthCm</th>
#       <th id="T_6c18d_level0_col2" class="col_heading level0 col2" >SepalWidthCm</th>
#       <th id="T_6c18d_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_6c18d_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#       <th id="T_6c18d_level0_col5" class="col_heading level0 col5" >Species</th>
#       <th id="T_6c18d_level0_col6" class="col_heading level0 col6" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c18d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c18d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6c18d_row0_col1" class="data row0 col1" >5.100000</td>
# ...

# %%
df.isnull()
#if there is data is missing, it will display True else False.
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
#      total_values
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# total_values     0
# dtype: int64

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# A corelation matrix is a table showing corelation coefficients between variables. Each cell in the table shows the correlation between two variables. The value is in the range of -1 to 1. if two variables have high corelation between them we can neglect one variable from two
#
# [cmap = 'coolwarm' ]= it is used to change the colour of heatmap

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# total_values   0.852006       0.940817     -0.214516       0.971404
#
#                PetalWidthCm  total_values
# Id                 0.899759      0.852006
# SepalLengthCm      0.817954      0.940817
# SepalWidthCm      -0.356544     -0.214516
# PetalLengthCm      0.962757      0.971404
# PetalWidthCm       1.000000      0.954109
# total_values       0.954109      1.000000

# %%
g = sns.pairplot(df,hue="Species")

# %% [markdown]
# # Heatmap:

# %% [markdown]
# 1.The heatmap is a data visualisation technique which is used to analyse the dataset as colors in two dimensions.
#
# 2.Basically it shows correlation between all numerical variables in the dataset.
#
# 3.Heatmap is an attribute of the Seaborn library.
#
# 4.Annotate each cell with the numeric value using integer formatting

# %%
corr = df.corr()
fig , ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr , annot=True, ax=ax, cmap = 'coolwarm',linecolor = 'white',linewidths = 1)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
fig , ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr , annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Label Encoder

# %% [markdown]
# 1.In machine learning we usually deal with datasets which contains multiple labels in one or more than one columns.
#
# 2.These labels can be in the form of words or numbers.
#
# 3.Label encoding refers to converting the labels into numeric form so as to convert it into the machine-readable form.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0
#
#    total_values
# 0          10.2
# 1           9.5
# 2           9.4
# 3           9.4
# 4          10.2

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
#training and testing
#train - 70
#test - 30
X  = df.drop(columns=['Species'])
Y= df['Species']
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.30)
